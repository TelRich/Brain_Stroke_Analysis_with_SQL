# %%
import pandas as pd

# %%
# importing required package
import sqlite3 as sq
import plotly.graph_objs as go
import plotly.express as px

# %%
# Creating Database
conn = sq.connect('brain_stroke.db')

# Create a table called brainStroke
query = """
CREATE TABLE brainStroke(
    gender VARCHAR(10),
    age DECIMAL(4,1),
    hypertension SMALLINT,
    heart_disease SMALLINT,
    ever_married VARCHAR(5),
    work_type VARCHAR(20),
    residence_type VARCHAR(10),
    avg_glucose_level DECIMAL(5,2),
    bmi DECIMAL(4,1),
    smoking_status VARCHAR(15),
    stroke SMALLINT
)
"""

# %%
with conn:
    cur = conn.cursor()
    cur.execute("DROP TABLE IF EXISTS brainStroke")
    cur.execute(query)

# %%
# check our sqlite master for confirmation
query = "SELECT name FROM sqlite_master WHERE type='table'"
cur.execute(query)
cur.fetchall()
# Out:
# [('brainStroke',)]

# %%
brain_df = pd.read_csv('brain_stroke.csv')

# %%
brain_df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
csv_tuple = tuple(brain_df.itertuples(index=False, name=None))
csv_tuple[0]
# Out:
# ('Male',
#  67.0,
#  0,
#  1,
#  'Yes',
#  'Private',
#  'Urban',
#  228.69,
#  36.6,
#  'formerly smoked',
#  1)

# %%
insert_query = "INSERT INTO brainStroke VALUES(?,?,?,?,?,?,?,?,?,?,?)"
cur.executemany(insert_query, csv_tuple)

# %%
query = "SELECT * FROM brainStroke LIMIT 5"
# cur.execute(query)
# cur.fetchall()

# %%
pd.read_sql_query(query, conn)
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1    Male   80             0              1          Yes        Private
# 2  Female   49             0              0          Yes        Private
# 3  Female   79             1              0          Yes  Self-employed
# 4    Male   81             0              0          Yes        Private
#
#   residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
query = """
SELECT gender, COUNT(*) count
FROM brainStroke
GROUP BY gender
"""
pd.read_sql_query(query, conn)
# Out:
#    gender  count
# 0  Female   2907
# 1    Male   2074

# %%
query = """
SELECT gender, stroke, COUNT(*) count
FROM brainStroke
GROUP BY gender, stroke
"""
pd.read_sql_query(query, conn)
# Out:
#    gender  stroke  count
# 0  Female       0   2767
# 1  Female       1    140
# 2    Male       0   1966
# 3    Male       1    108

# %%
query = """
SELECT gender, COUNT(*) has_both_hyptnsn_hrt_dis
FROM brainStroke
WHERE hypertension = 1 AND heart_disease = 1
GROUP BY gender
"""
pd.read_sql_query(query, conn)
# Out:
#    gender  has_both_hyptnsn_hrt_dis
# 0  Female                        29
# 1    Male                        35

# %%
query = """
SELECT residence_type, stroke,  COUNT(*) count
FROM brainStroke 
GROUP BY residence_type, stroke
"""
pd.read_sql_query(query, conn)
# Out:
#   residence_type  stroke  count
# 0          Rural       0   2336
# 1          Rural       1    113
# 2          Urban       0   2397
# 3          Urban       1    135

# %%
query = """
SELECT MAX(age) max_age, MIN(age) min_age, AVG(age) avg_age
FROM brainStroke
"""
pd.read_sql_query(query, conn)
# Out:
#    max_age  min_age    avg_age
# 0       82     0.08  43.419859

# %%
query = """
SELECT *
FROM brainStroke
WHERE age < 1
LIMIT 10
"""
pd.read_sql_query(query, conn)
# Out:
#    gender   age  hypertension  heart_disease ever_married work_type  \
# 0  Female  0.64             0              0           No  children
# 1  Female  0.88             0              0           No  children
# 2  Female  0.32             0              0           No  children
# 3    Male  0.88             0              0           No  children
# 4    Male  0.24             0              0           No  children
# 5  Female  0.32             0              0           No  children
# 6  Female  0.72             0              0           No  children
# 7    Male  0.80             0              0           No  children
# 8    Male  0.40             0              0           No  children
# 9  Female  0.08             0              0           No  children
#
#   residence_type  avg_glucose_level   bmi smoking_status  stroke
# 0          Urban              83.82  24.9        Unknown       0
# 1          Rural              88.11  15.5        Unknown       0
# 2          Rural              73.71  16.2        Unknown       0
# 3          Rural             157.57  19.2        Unknown       0
# 4          Rural             118.87  16.3        Unknown       0
# 5          Rural              55.86  16.0        Unknown       0
# 6          Urban              66.36  23.0        Unknown       0
# 7          Rural              98.67  17.5        Unknown       0
# 8          Urban             109.56  14.3        Unknown       0
# 9          Urban             139.67  14.1        Unknown       0

# %%
query = """
SELECT DISTINCT(work_type)
FROM brainStroke
"""
pd.read_sql_query(query, conn)
# Out:
#        work_type
# 0        Private
# 1  Self-employed
# 2       Govt_job
# 3       children
